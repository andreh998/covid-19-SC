# %% [markdown]
# # Análise dos casos de Covid-19 em Santa Catarina

# %%
# bibliotecas
import pandas as pd
import folium
import requests
import json

# %matplotlib inline

# %%
# URL da api com os dados
url = 'https://brasil.io/api/dataset/covid19/caso/data?state=SC'
# Pego o retorno da api e salvo em 'response'
response = requests.get(url)
# Mostro a resposta do retorno
# response.text

# %%
# Crio um dataframe com os dados da primeira página da api
df_dados = pd.DataFrame(response.json()['results'])

df_dados.head()
# Out:
#               city city_ibge_code  confirmed  confirmed_per_100k_inhabitants  \
# 0     Águas Mornas        4200606          1                        15.45834
# 1  Anita Garibaldi        4201000          1                        14.01935
# 2   Antônio Carlos        4201208         11                       129.21414
# 3        Araranguá        4201406          4                         5.86270
# 4           Aurora        4201901          1                        17.60873
#
#          date  death_rate  deaths  estimated_population_2019  is_last  \
# 0  2020-04-14         NaN       0                     6469.0     True
# 1  2020-04-14         NaN       0                     7133.0     True
# 2  2020-04-14      0.2727       3                     8513.0     True
# 3  2020-04-14         NaN       0                    68228.0     True
# 4  2020-04-14         NaN       0                     5679.0     True
#
#    order_for_place place_type state
# 0                9       city    SC
# 1                8       city    SC
# 2               19       city    SC
# 3               12       city    SC
# 4                6       city    SC

# %%
df_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
# city                              985 non-null object
# city_ibge_code                    984 non-null object
# confirmed                         1000 non-null int64
# confirmed_per_100k_inhabitants    982 non-null float64
# date                              1000 non-null object
# death_rate                        172 non-null float64
# deaths                            1000 non-null int64
# estimated_population_2019         984 non-null float64
# is_last                           1000 non-null bool
# order_for_place                   1000 non-null int64
# place_type                        1000 non-null object
# state                             1000 non-null object
# dtypes: bool(1), float64(3), int64(3), object(5)
# memory usage: 87.0+ KB

# %%
# Como a API possui muitos dados, eles podem ser divididos em várias páginas
# Vou verificar se existem mais páginas e incluí-las no df_dados

parsed = json.loads(response.text)
next_page = parsed['next']

while next_page:
    res = requests.get(next_page)
    res.text
    df = pd.DataFrame(res.json()['results'])
    df_dados = df_dados.append(df)
    parsed = json.loads(res.text)
    next_page = parsed['next']
    
    
df_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1328 entries, 0 to 327
# Data columns (total 12 columns):
# city                              1294 non-null object
# city_ibge_code                    1307 non-null object
# confirmed                         1328 non-null int64
# confirmed_per_100k_inhabitants    1304 non-null float64
# date                              1328 non-null object
# death_rate                        182 non-null float64
# deaths                            1328 non-null int64
# estimated_population_2019         1307 non-null float64
# is_last                           1328 non-null bool
# order_for_place                   1328 non-null int64
# place_type                        1328 non-null object
# state                             1328 non-null object
# dtypes: bool(1), float64(3), int64(3), object(5)
# memory usage: 125.8+ KB

# %%
df_dados.head(100)
# Out:
#                   city city_ibge_code  confirmed  \
# 0         Águas Mornas        4200606          1
# 1      Anita Garibaldi        4201000          1
# 2       Antônio Carlos        4201208         11
# 3            Araranguá        4201406          4
# 4               Aurora        4201901          1
# ..                 ...            ...        ...
# 95  Balneário Piçarras        4212809          2
# 96         Barra Velha        4202107          1
#            date  death_rate  deaths  estimated_population_2019  is_last  \
# 22   2020-04-14      0.0145       3                   500973.0     True
# 109  2020-04-13      0.0151       3                   500973.0    False
# 195  2020-04-12      0.0169       3                   500973.0    False
# 278  2020-04-11      0.0173       3                   500973.0    False
# 360  2020-04-10      0.0180       3                   500973.0    False
# 441  2020-04-09      0.0181       3                   500973.0    False
# 516  2020-04-08      0.0244       3                   500973.0    False
# 583  2020-04-07      0.0263       3                   500973.0    False
# 645  2020-04-06      0.0202       2                   500973.0    False
# 703  2020-04-05      0.0213       2                   500973.0    False
# 758  2020-04-04      0.0220       2                   500973.0    False
# 811  2020-04-03      0.0128       1                   500973.0    False
# 860  2020-04-02      0.0141       1                   500973.0    False
# 903  2020-04-01         NaN       0                   500973.0    False
# 944  2020-03-31         NaN       0                   500973.0    False
# 985  2020-03-30         NaN       0                   500973.0    False
# 26   2020-03-29         NaN       0                   500973.0    False
# 66   2020-03-28         NaN       0                   500973.0    False
# 104  2020-03-27         NaN       0                   500973.0    False
# 138  2020-03-26         NaN       0                   500973.0    False
# 171  2020-03-25         NaN       0                   500973.0    False
# 198  2020-03-24         NaN       0                   500973.0    False
# 222  2020-03-23         NaN       0                   500973.0    False
# 244  2020-03-22         NaN       0                   500973.0    False
# 262  2020-03-21         NaN       0                   500973.0    False
# 279  2020-03-20         NaN       0                   500973.0    False
# 291  2020-03-19         NaN       0                   500973.0    False
# 299  2020-03-18         NaN       0                   500973.0    False
# 305  2020-03-17         NaN       0                   500973.0    False
# 310  2020-03-16         NaN       0                   500973.0    False
# 315  2020-03-15         NaN       0                   500973.0    False
# 319  2020-03-14         NaN       0                   500973.0    False
# 323  2020-03-13         NaN       0                   500973.0    False
# 326  2020-03-12         NaN       0                   500973.0    False
#
#      order_for_place place_type state
# 22                34       city    SC
# 109               33       city    SC
# 195               32       city    SC
# 278               31       city    SC
# 360               30       city    SC
# 441               29       city    SC
# 516               28       city    SC
# 583               27       city    SC
# 645               26       city    SC
# 703               25       city    SC
# 758               24       city    SC
# 811               23       city    SC
# 860               22       city    SC
# 903               21       city    SC
# 944               20       city    SC
# 985               19       city    SC
# 26                18       city    SC
# 66                17       city    SC
# 104               16       city    SC
# 138               15       city    SC
# 171               14       city    SC
# 198               13       city    SC
# 222               12       city    SC
# 244               11       city    SC
# 262               10       city    SC
# 279                9       city    SC
# 291                8       city    SC
# 299                7       city    SC
# 305                6       city    SC
# 310                5       city    SC
# 315                4       city    SC
# 319                3       city    SC
# 323                2       city    SC
# 326                1       city    SC

# %%
# E da mesma forma retorna a quantidade de casos totais do estado no último mês
df_dados[df_dados['place_type'] == 'state']
# Out:
#      city city_ibge_code  confirmed  confirmed_per_100k_inhabitants  \
# 86   None             42        853                        11.90545
# 173  None             42        826                        11.52860
# 256  None             42        776                        10.83075
# 338  None             42        732                        10.21663
# 419  None             42        717                        10.00727
# 499  None             42        693                         9.67230
# 566               28      state    SC
# 629               27      state    SC
# 689               26      state    SC
# 744               25      state    SC
# 798               24      state    SC
# 848               23      state    SC
# 892               22      state    SC
# 933               21      state    SC
# 974               20      state    SC
# 15                19      state    SC
# 55                18      state    SC
# 94                17      state    SC
# 129               16      state    SC
# 162               15      state    SC
# 192               14      state    SC
# 216               13      state    SC
# 238               12      state    SC
# 257               11      state    SC
# 274               10      state    SC
# 288                9      state    SC
# 296                8      state    SC
# 303                7      state    SC
# 308                6      state    SC
# 313                5      state    SC
# 318                4      state    SC
# 322                3      state    SC
# 325                2      state    SC
# 327                1      state    SC

# %% [markdown]
# # Ajuste do dataframe com os dados de localização dos municípios
#
# Depois de obter todos os dados referentes aos casos, resta criar um dataframe com as localizações dos municípios do estado.

# %%
# Carregar arquivos com as localizações

# Crio um dataframe com os estados
df_estados = pd.read_csv('./data/estados.csv')

# Crio um dataframe com os municípios
df_muni = pd.read_csv('./data/municipios.csv')

# %%
# Visualizar o dataframe de estados
df_estados.head(27)
# Out:
#     codigo_uf  uf                 nome
# 0          11  RO             Rondônia
# 1          12  AC                 Acre
# 2          13  AM             Amazonas
# 3          14  RR              Roraima
# 4          15  PA                 Pará
# 5          16  AP                Amapá
# 6          17  TO            Tocantins
# 7          21  MA             Maranhão
# 8          22  PI                Piauí
# 9          23  CE                Ceará
# 10         24  RN  Rio Grande do Norte
# 11         25  PB              Paraíba
# 12         26  PE           Pernambuco
# 13         27  AL              Alagoas
# 14         28  SE              Sergipe
# 15         29  BA                Bahia
# 16         31  MG         Minas Gerais
# 17         32  ES       Espírito Santo
# 18         33  RJ       Rio de Janeiro
# 19         35  SP            São Paulo
# 20         41  PR               Paraná
# 21         42  SC       Santa Catarina
# 22         43  RS    Rio Grande do Sul
# 23         50  MS   Mato Grosso do Sul
# 24         51  MT          Mato Grosso
# 25         52  GO                Goiás
# 26         53  DF     Distrito Federal

# %%
# Visualizar o dataframe de municípios
df_muni.head(20)
# Out:
#     codigo_ibge                 nome  latitude  longitude  capital  codigo_uf
# 0       5200050      Abadia de Goiás -16.75730   -49.4412        0         52
# 1       3100104  Abadia dos Dourados -18.48310   -47.3916        0         31
# 2       5200100            Abadiânia -16.19700   -48.7057        0         52
# 3       3100203               Abaeté -19.15510   -45.4444        0         31
# 4       1500107           Abaetetuba  -1.72183   -48.8788        0         15
# 5       2300101              Abaiara  -7.34588   -39.0416        0         23
# 6       2900108               Abaíra -13.24880   -41.6619        0         29
# 7       2900207                Abaré  -8.72073   -39.1162        0         29
# 8       4100103               Abatiá -23.30490   -50.3133        0         41
# 9       4200051        Abdon Batista -27.61260   -51.0233        0         42
# 10      1500131      Abel Figueiredo  -4.95333   -48.3933        0         15
# 11      4200101         Abelardo Luz -26.57160   -52.3229        0         42
# 12      3100302           Abre Campo -20.29960   -42.4743        0         31
# 13      2600054         Abreu e Lima  -7.90072   -34.8984        0         26
# 14      1700251          Abreulândia  -9.62101   -49.1518        0         17
# 15      3100401              Acaiaca -20.35900   -43.1439        0         31
# 16      2100055           Açailândia  -4.94714   -47.5004        0         21
# 17      2900306            Acajutiba -11.65750   -38.0197        0         29
# 18      1500206                Acará  -1.95383   -48.1985        0         15
# 19      2300150              Acarape  -4.22083   -38.7055        0         23

# %%
# Como quero apenas os municípios de SC, devo analisar o dataframe df_muni e separar os municípios.
# Ao olhar no dataframe de estados, podemos identificar que o código da UF de SC é 42
# Então podemos ver no dataframe de municípios quantos que pertencem ao código da UF 42
df_muni[df_muni['codigo_uf'] == 42].count()
# Out:
# codigo_ibge    295
# nome           295
# latitude       295
# longitude      295
# capital        295
# codigo_uf      295
# dtype: int64

# %%
# Criarei um dataframe separado apenas com os municípios de SC
df_sc = df_muni[df_muni['codigo_uf'] == 42].copy()

df_sc.head()
# Out:
#     codigo_ibge           nome  latitude  longitude  capital  codigo_uf
# 9       4200051  Abdon Batista  -27.6126   -51.0233        0         42
# 11      4200101   Abelardo Luz  -26.5716   -52.3229        0         42
# 43      4200200     Agrolândia  -27.4087   -49.8220        0         42
# 44      4200309     Agronômica  -27.2662   -49.7080        0         42
# 53      4200408      Água Doce  -26.9985   -51.5528        0         42

# %%
# Verifico se o tamanho do dataframe confere com o número de municípios pertencentes ao estado que é 295
df_sc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 295 entries, 9 to 5569
# Data columns (total 6 columns):
# codigo_ibge    295 non-null int64
# nome           295 non-null object
# latitude       295 non-null float64
# longitude      295 non-null float64
# capital        295 non-null int64
# codigo_uf      295 non-null int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 16.1+ KB

# %%
df_dados.head()
# Out:
#               city city_ibge_code  confirmed  confirmed_per_100k_inhabitants  \
# 0     Águas Mornas        4200606          1                        15.45834
# 1  Anita Garibaldi        4201000          1                        14.01935
# 2   Antônio Carlos        4201208         11                       129.21414
# 3        Araranguá        4201406          4                         5.86270
# 4           Aurora        4201901          1                        17.60873
#
#          date  death_rate  deaths  estimated_population_2019  is_last  \
# 0  2020-04-14         NaN       0                     6469.0     True
# 1  2020-04-14         NaN       0                     7133.0     True
# 2  2020-04-14      0.2727       3                     8513.0     True
# 3  2020-04-14         NaN       0                    68228.0     True
# 4  2020-04-14         NaN       0                     5679.0     True
#
#    order_for_place place_type state
# 0                9       city    SC
# 1                8       city    SC
# 2               19       city    SC
# 3               12       city    SC
# 4                6       city    SC

# %%
# Crio duas cópias dos dataframes df_sc e df_dados para manter um backup
# Caso de algum problema não preciso executar o notebook todo novamente
df_sc_cp = df_sc.copy()
df_dados_cp = df_dados.copy()

# %%
df_dados_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1328 entries, 0 to 327
# Data columns (total 12 columns):
# city                              1294 non-null object
# city_ibge_code                    1307 non-null object
# confirmed                         1328 non-null int64
# confirmed_per_100k_inhabitants    1304 non-null float64
# date                              1328 non-null object
# death_rate                        182 non-null float64
# deaths                            1328 non-null int64
# estimated_population_2019         1307 non-null float64
# is_last                           1328 non-null bool
# order_for_place                   1328 non-null int64
# place_type                        1328 non-null object
# state                             1328 non-null object
# dtypes: bool(1), float64(3), int64(3), object(5)
# memory usage: 125.8+ KB

# %%
df_dados_cp[df_dados_cp['city_ibge_code'].isnull()]
# Out:
#                        city city_ibge_code  confirmed  \
# 32   Importados/Indefinidos           None         12
# 119  Importados/Indefinidos           None         11
# 205  Importados/Indefinidos           None         11
# 288  Importados/Indefinidos           None         11
# 370  Importados/Indefinidos           None          8
# 451  Importados/Indefinidos           None         11
# 524  Importados/Indefinidos           None         11
# 589  Importados/Indefinidos           None         10
# 651  Importados/Indefinidos           None         10
# 709  Importados/Indefinidos           None          9
# 764  Importados/Indefinidos           None          9
# 817  Importados/Indefinidos           None          8
# 865  Importados/Indefinidos           None          8
# 908  Importados/Indefinidos           None          8
# 949  Importados/Indefinidos           None          8
# 990  Importados/Indefinidos           None          8
# 31   Importados/Indefinidos           None          8
# 71   Importados/Indefinidos           None          8
# 109  Importados/Indefinidos           None          8
# 143  Importados/Indefinidos           None          8
# 176  Importados/Indefinidos           None          8
#
#      confirmed_per_100k_inhabitants        date  death_rate  deaths  \
# 32                              NaN  2020-04-14         NaN       0
# 119                             NaN  2020-04-13         NaN       0
# 205                             NaN  2020-04-12         NaN       0
# 288                             NaN  2020-04-11         NaN       0
# 370                             NaN  2020-04-10         NaN       0
# 451                             NaN  2020-04-09         NaN       0
# 524                             NaN  2020-04-08         NaN       0
# 589                             NaN  2020-04-07         NaN       0
# 651                             NaN  2020-04-06         NaN       0
# 709                             NaN  2020-04-05         NaN       0
# 764                             NaN  2020-04-04         NaN       0
# 817                             NaN  2020-04-03         NaN       0
# 865                             NaN  2020-04-02         NaN       0
# 908                             NaN  2020-04-01         NaN       0
# 949                             NaN  2020-03-31         NaN       0
# 990                             NaN  2020-03-30         NaN       0
# 31                              NaN  2020-03-29         NaN       0
# 71                              NaN  2020-03-28         NaN       0
# 109                             NaN  2020-03-27         NaN       0
# 143                             NaN  2020-03-26         NaN       0
# 176                             NaN  2020-03-25         NaN       0
#
#      estimated_population_2019  is_last  order_for_place place_type state
# 32                         NaN     True               21       city    SC
# 119                        NaN    False               20       city    SC
# 205                        NaN    False               19       city    SC
# 288                        NaN    False               18       city    SC
# 370                        NaN    False               17       city    SC
# 451                        NaN    False               16       city    SC
# 524                        NaN    False               15       city    SC
# 589                        NaN    False               14       city    SC
# 651                        NaN    False               13       city    SC
# 709                        NaN    False               12       city    SC
# 764                        NaN    False               11       city    SC
# 817                        NaN    False               10       city    SC
# 865                        NaN    False                9       city    SC
# 908                        NaN    False                8       city    SC
# 949                        NaN    False                7       city    SC
# 990                        NaN    False                6       city    SC
# 31                         NaN    False                5       city    SC
# 71                         NaN    False                4       city    SC
# 109                        NaN    False                3       city    SC
# 143                        NaN    False                2       city    SC
# 176                        NaN    False                1       city    SC

# %%
df_sc_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 295 entries, 9 to 5569
# Data columns (total 6 columns):
# codigo_ibge    295 non-null int64
# nome           295 non-null object
# latitude       295 non-null float64
# longitude      295 non-null float64
# capital        295 non-null int64
# codigo_uf      295 non-null int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 16.1+ KB

# %%
# É preciso juntar o dataframe dos municípios com o dataframe de dados
# pois o dataframe de dados não possui as informações de latitude e longitude de cada município.
# Como nos dois dataframes temos o código IBGE da cidade, podemos uní-los através dele

# Para juntar os dois dataframes eu vou transformar a coluna do código do IBGE de cada dataframe em indice,
# dessa forma, no momento de fazer o join ele vai unir as colunas com o mesmo indice, então sempre que achar um 
# indice no dataframe dos dados com o mesmo indice do dataframe com as localizações ele vai unir as informações

# Porém para funcionar, os indices devem ser do mesmo tipo, e identifiquei com o comando .info() 
# que a coluna do código IBGE no dataframe de dados é do tipo 'object' e a coluna referente ao código IBGE 
# no dataframe com as cidades e localizações, é do tipo 'int'

# Sendo assim vou converter a coluna do df_sc_cp para object. Mas porque object e não para int?
# Porque temos no dataframe de dados, uma informação onde a cidade corresponde a outros estados ou outros países
# e nessa informação não temos o código do IBGE, então ele não é um inteiro e não pode ser convertido para int

# Outra maneira seria alterar esse código do IBGE correspondente a outros estados e países para um valor numérico
# e depois converter a coluna toda para int

# Convertendo a coluna 'codigo_ibge' do dataframe com as localizações para uma string
df_sc_cp['codigo_ibge'] = df_sc_cp['codigo_ibge'].astype(str)

# %%
df_sc_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 295 entries, 9 to 5569
# Data columns (total 6 columns):
# codigo_ibge    295 non-null object
# nome           295 non-null object
# latitude       295 non-null float64
# longitude      295 non-null float64
# capital        295 non-null int64
# codigo_uf      295 non-null int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 16.1+ KB

# %%
# Fetias as conversões, deixo o código do IBGE da cidade como indice em cada dataframe
df_sc_cp.set_index('codigo_ibge', drop=False, inplace=True)
df_dados_cp.set_index('city_ibge_code', drop=False, inplace=True)

# %%
# Faço a união dos dataframes em um novo.
df_final = df_dados_cp.join(df_sc_cp)

# %%
df_final.sample(10)
# Out:
#                            city city_ibge_code  confirmed  \
# 4207304                Imbituba        4207304          5
# 4204202                 Chapecó        4204202          5
# 4202909                 Brusque        4202909         16
# 4209102               Joinville        4209102         51
# 42                         None             42        235
# 4201901                  Aurora        4201901          1
# 4203006                 Caçador        4203006          3
# 42                         None             42        247
# 42                         None             42          7
# NaN      Importados/Indefinidos           None         11
#
#          confirmed_per_100k_inhabitants        date  death_rate  deaths  \
# 4207304                        11.14753  2020-04-02         NaN       0
# 4204202                         2.26894  2020-04-01         NaN       0
# 4202909                        11.87622  2020-04-11         NaN       0
# 4209102                         8.63725  2020-04-10      0.0196       1
# 42                              3.27993  2020-03-31      0.0085       2
# 4201901                        17.60873  2020-04-09         NaN       0
# 4203006                         3.81704  2020-04-13         NaN       0
# 42                              3.44742  2020-04-01      0.0081       2
# 42                              0.09770  2020-03-16         NaN       0
# NaN                                 NaN  2020-04-13         NaN       0
#
#          estimated_population_2019  is_last  order_for_place place_type state  \
# 4207304                    44853.0    False               14       city    SC
# 4204202                   220367.0    False               13       city    SC
# 4202909                   134723.0    False               15       city    SC
# 4209102                   590466.0    False               29       city    SC
# 42                       7164788.0    False               20      state    SC
# 4201901                     5679.0    False                1       city    SC
# 4203006                    78595.0    False                5       city    SC
# 42                       7164788.0    False               21      state    SC
# 42                       7164788.0    False                5      state    SC
# NaN                            NaN    False               20       city    SC
#
#         codigo_ibge       nome  latitude  longitude  capital  codigo_uf
# 4207304     4207304   Imbituba  -28.2284   -48.6659      0.0       42.0
# 4204202     4204202    Chapecó  -27.1004   -52.6152      0.0       42.0
# 4202909     4202909    Brusque  -27.0977   -48.9107      0.0       42.0
# 4209102     4209102  Joinville  -26.3045   -48.8487      0.0       42.0
# 42              NaN        NaN       NaN        NaN      NaN        NaN
# 4201901     4201901     Aurora  -27.3098   -49.6295      0.0       42.0
# 4203006     4203006    Caçador  -26.7757   -51.0120      0.0       42.0
# 42              NaN        NaN       NaN        NaN      NaN        NaN
# 42              NaN        NaN       NaN        NaN      NaN        NaN
# NaN             NaN        NaN       NaN        NaN      NaN        NaN

# %%
# Como nos dados além dos municípios, tínhamos o histórico de casos no estado todo, 
# e também aqueles dados de 'outros países e estados' (que acredito ser de Catarinenses com casos confirmados, 
# mas que não estão em Santa Catarina), esses dados não foram unidos com o outro dataframe:
df_final[df_final['place_type'] == 'state'].head()
# Out:
#     city city_ibge_code  confirmed  confirmed_per_100k_inhabitants  \
# 42  None             42        853                        11.90545
# 42  None             42        826                        11.52860
# 42  None             42        776                        10.83075
# 42  None             42        732                        10.21663
# 42  None             42        717                        10.00727
#
#           date  death_rate  deaths  estimated_population_2019  is_last  \
# 42  2020-04-14      0.0328      28                  7164788.0     True
# 42  2020-04-13      0.0315      26                  7164788.0    False
# 42  2020-04-12      0.0309      24                  7164788.0    False
# 42  2020-04-11      0.0287      21                  7164788.0    False
# 42  2020-04-10      0.0251      18                  7164788.0    False
#
#     order_for_place place_type state codigo_ibge nome  latitude  longitude  \
# 42               34      state    SC         NaN  NaN       NaN        NaN
# 42               33      state    SC         NaN  NaN       NaN        NaN
# 42               32      state    SC         NaN  NaN       NaN        NaN
# 42               31      state    SC         NaN  NaN       NaN        NaN
# 42               30      state    SC         NaN  NaN       NaN        NaN
#
#     capital  codigo_uf
# 42      NaN        NaN
# 42      NaN        NaN
# 42      NaN        NaN
# 42      NaN        NaN
# 42      NaN        NaN

# %%
df_final[df_final['city'] == 'Importados/Indefinidos']
# Out:
#                        city city_ibge_code  confirmed  \
# NaN  Importados/Indefinidos           None         12
# NaN  Importados/Indefinidos           None         11
# NaN  Importados/Indefinidos           None         11
# NaN  Importados/Indefinidos           None         11
# NaN  Importados/Indefinidos           None          8
# NaN  Importados/Indefinidos           None         11
# NaN  Importados/Indefinidos           None         11
# NaN  Importados/Indefinidos           None         10
# NaN  Importados/Indefinidos           None         10
# NaN  Importados/Indefinidos           None          9
# NaN  Importados/Indefinidos           None          9
# NaN  Importados/Indefinidos           None          8
# NaN  Importados/Indefinidos           None          8
# NaN  Importados/Indefinidos           None          8
# NaN  Importados/Indefinidos           None          8
# NaN  Importados/Indefinidos           None          8
# NaN  Importados/Indefinidos           None          8
# NaN  Importados/Indefinidos           None          8
# NaN  Importados/Indefinidos           None          8
# NaN  Importados/Indefinidos           None          8
# NaN  Importados/Indefinidos           None          8
#
#      confirmed_per_100k_inhabitants        date  death_rate  deaths  \
# NaN                             NaN  2020-04-14         NaN       0
# NaN                             NaN  2020-04-13         NaN       0
# NaN                             NaN  2020-04-12         NaN       0
# NaN                             NaN  2020-04-11         NaN       0
# NaN                             NaN  2020-04-10         NaN       0
# NaN                             NaN  2020-04-09         NaN       0
# NaN                             NaN  2020-04-08         NaN       0
# NaN                             NaN  2020-04-07         NaN       0
# NaN                             NaN  2020-04-06         NaN       0
# NaN                             NaN  2020-04-05         NaN       0
# NaN                             NaN  2020-04-04         NaN       0
# NaN                             NaN  2020-04-03         NaN       0
# NaN                             NaN  2020-04-02         NaN       0
# NaN                             NaN  2020-04-01         NaN       0
# NaN                             NaN  2020-03-31         NaN       0
# NaN                             NaN  2020-03-30         NaN       0
# NaN                             NaN  2020-03-29         NaN       0
# NaN                             NaN  2020-03-28         NaN       0
# NaN                             NaN  2020-03-27         NaN       0
# NaN                             NaN  2020-03-26         NaN       0
# NaN                             NaN  2020-03-25         NaN       0
#
#      estimated_population_2019  is_last  order_for_place place_type state  \
# NaN                        NaN     True               21       city    SC
# NaN                        NaN    False               20       city    SC
# NaN                        NaN    False               19       city    SC
# NaN                        NaN    False               18       city    SC
# NaN                        NaN    False               17       city    SC
# NaN                        NaN    False               16       city    SC
# NaN                        NaN    False               15       city    SC
# NaN                        NaN    False               14       city    SC
# NaN                        NaN    False               13       city    SC
# NaN                        NaN    False               12       city    SC
# NaN                        NaN    False               11       city    SC
# NaN                        NaN    False               10       city    SC
# NaN                        NaN    False                9       city    SC
# NaN                        NaN    False                8       city    SC
# NaN                        NaN    False                7       city    SC
# NaN                        NaN    False                6       city    SC
# NaN                        NaN    False                5       city    SC
# NaN                        NaN    False                4       city    SC
# NaN                        NaN    False                3       city    SC
# NaN                        NaN    False                2       city    SC
# NaN                        NaN    False                1       city    SC
#
#     codigo_ibge nome  latitude  longitude  capital  codigo_uf
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN
# NaN         NaN  NaN       NaN        NaN      NaN        NaN

# %%
# Como definimos o indice dos dados como sendo o código do IBGE as cidades correspondetes 
# a 'Importados/Indefinidos' ficaram sem indice

# %% [markdown]
# # Gerando os mapas

# %%
# Crio um mapa com base na localização de Santa Catarina
sc = folium.Map(
        location=[-27.097889, -51.150770], # Cordenadas do google maps
        zoom_start=7
)

# %%
# Percorro o dataframe pegando os locais com casos
# e desenhar um marcador para cada cidade

for indice, municipio in df_final[(df_final['confirmed'] > 0) & (df_final['city'] != 'Importados/Indefinidos')
                                 & (df_final['place_type'] != 'state') & (df_final['is_last'] == True)].iterrows():
    folium.Marker(
        location=[municipio['latitude'], municipio['longitude']],
        popup= '%s, %s Caso(s) ' %(municipio['city'], municipio['confirmed']),
        icon=folium.map.Icon(color='green')
    ).add_to(sc)
    
# Mostra o mapa
sc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
